# %% [markdown]
# # ACVR1/FOP Demo
#
# Placeholder notebook for the end-to-end BioAutoScientist demo. Use the API endpoints to create an objective, start a run, fetch trace, inspect board posts, and export the final report.
